# %% [markdown]
# ## Next Word Prediction Using LSTM

# %% [markdown]
# #### Why LSTM is needed for Next Word Prediction ?
#
# #### * ANN --> No-Memory
# #### * CNN --> Spatial Pattern ( Image)
# #### * RNN --> Short Term Memory & No access to Long-Term Memory
#
# ### * LSTM --> Long Term Memory
# #### Language Needs  --> Word Order --> context --> Long Term Dependency --> LSTM designed for this Special Task

# %% [markdown]
# ### High Level Architecture :-->
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Next Word Prediction can be Treated as ta Text Generator --> Supervised Learning

# %% [markdown]
# ### Supervised Learning --> Right Now --> SupervisedX --> we have to convert this task into a Supervised...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 1. Data Gathering

# %% [markdown]
# ### Step 2. Tokenizer --> [convert Text --> Numbers ] --Using --> pad_sequences
# * Tokenizer --> Scan the text
#
# ### Step 3.Embedding --> give Words Meaning
#
# ### Step 4. LSTM --> learns context
#
# ### Step 5. Dense --> Predict Next Word

# %% [markdown]
# ### Next Word Prediction  --> Language Modeling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  How to Imporve Performace of this Model ?
#
# #### 1. More Data  --> better Result
# #### 2. Hyperparameter Tuning --> Better Decision about the parameter
# #### 3. Advamced Architecture --> Transformaer , Bidirectional LSTM , More LSTM
